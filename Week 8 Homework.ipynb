# %%
#imports
from datetime import date
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
class Homework:
    def __init__(self, Experimenter, Date = date.today(), FilePath = '/Users/nikko/Documents/intro2python/recording.npy'):
        self.date = Date
        self.filepath = FilePath
        self.experimenter = Experimenter
        self.data = np.load(FilePath)
    def plot_data(self, NeuronNumber):
        plt.hist(self.data[:,NeuronNumber])
        plt.show()
    def __str__(self):
        return f"Data from {self.filepath} recorded by {self.experimenter} on {self.date}"
homework = Homework('Nikko')
homework.plot_data(50)
print(homework)
# Out:
# Data from /Users/nikko/Documents/intro2python/recording.npy recorded by Nikko on 2024-10-30
